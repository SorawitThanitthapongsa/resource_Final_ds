# %%
# import required libraries
from kafka import KafkaConsumer

# %%
# Connect to kafka broker running in your local host (docker). Change this to your kafka broker if needed
kafka_broker = 'localhost:9092'

# %%
consumer = KafkaConsumer(
     bootstrap_servers=[kafka_broker],
     enable_auto_commit=True,
     value_deserializer=lambda x: x.decode('utf-8'))

# %%
consumer.subscribe('sample')

# %%
print('Running Consumer #2')
while(True):
    results = consumer.poll(timeout_ms=1000)
    if len(results) == 0:
        print('no message')
    else:
        for tp, messages in results.items():
            print('topic = {} -- total {} messages'.format(tp.topic, len(messages)))
            print('-----')
            for message in messages:
                print(message)
    print('######################')
# Out:
# Running Consumer #2
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=61, timestamp=1679381456165, timestamp_type=0, key=None, value='message #56 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=62, timestamp=1679381456804, timestamp_type=0, key=None, value='message #5 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=63, timestamp=1679381458166, timestamp_type=0, key=None, value='message #57 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=64, timestamp=1679381459810, timestamp_type=0, key=None, value='message #6 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=65, timestamp=1679381460172, timestamp_type=0, key=None, value='message #58 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=66, timestamp=1679381462177, timestamp_type=0, key=None, value='message #59 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=67, timestamp=1679381462812, timestamp_type=0, key=None, value='message #7 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=68, timestamp=1679381464180, timestamp_type=0, key=None, value='message #60 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=69, timestamp=1679381465817, timestamp_type=0, key=None, value='message #8 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=70, timestamp=1679381466185, timestamp_type=0, key=None, value='message #61 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=71, timestamp=1679381468191, timestamp_type=0, key=None, value='message #62 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=72, timestamp=1679381468823, timestamp_type=0, key=None, value='message #9 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=73, timestamp=1679381470196, timestamp_type=0, key=None, value='message #63 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=74, timestamp=1679381471829, timestamp_type=0, key=None, value='message #10 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=75, timestamp=1679381472197, timestamp_type=0, key=None, value='message #64 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=76, timestamp=1679381474202, timestamp_type=0, key=None, value='message #65 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=77, timestamp=1679381474831, timestamp_type=0, key=None, value='message #11 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=78, timestamp=1679381476208, timestamp_type=0, key=None, value='message #66 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=79, timestamp=1679381477836, timestamp_type=0, key=None, value='message #12 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=80, timestamp=1679381478213, timestamp_type=0, key=None, value='message #67 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=81, timestamp=1679381480217, timestamp_type=0, key=None, value='message #68 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=82, timestamp=1679381480838, timestamp_type=0, key=None, value='message #13 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=83, timestamp=1679381482220, timestamp_type=0, key=None, value='message #69 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=84, timestamp=1679381483844, timestamp_type=0, key=None, value='message #14 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=85, timestamp=1679381484225, timestamp_type=0, key=None, value='message #70 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=86, timestamp=1679381486230, timestamp_type=0, key=None, value='message #71 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=87, timestamp=1679381486849, timestamp_type=0, key=None, value='message #15 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=88, timestamp=1679381488235, timestamp_type=0, key=None, value='message #72 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=89, timestamp=1679381489850, timestamp_type=0, key=None, value='message #16 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=90, timestamp=1679381490241, timestamp_type=0, key=None, value='message #73 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=91, timestamp=1679381492246, timestamp_type=0, key=None, value='message #74 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=92, timestamp=1679381492854, timestamp_type=0, key=None, value='message #17 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=93, timestamp=1679381494250, timestamp_type=0, key=None, value='message #75 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=94, timestamp=1679381495856, timestamp_type=0, key=None, value='message #18 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=95, timestamp=1679381496252, timestamp_type=0, key=None, value='message #76 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=96, timestamp=1679381498255, timestamp_type=0, key=None, value='message #77 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=97, timestamp=1679381498859, timestamp_type=0, key=None, value='message #19 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=98, timestamp=1679381500257, timestamp_type=0, key=None, value='message #78 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=99, timestamp=1679381501863, timestamp_type=0, key=None, value='message #20 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=100, timestamp=1679381502262, timestamp_type=0, key=None, value='message #79 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=101, timestamp=1679381504265, timestamp_type=0, key=None, value='message #80 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=102, timestamp=1679381504863, timestamp_type=0, key=None, value='message #21 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=103, timestamp=1679381506266, timestamp_type=0, key=None, value='message #81 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=104, timestamp=1679381507864, timestamp_type=0, key=None, value='message #22 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=105, timestamp=1679381508267, timestamp_type=0, key=None, value='message #82 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=106, timestamp=1679381510268, timestamp_type=0, key=None, value='message #83 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/ry/14q1qh192fd9xt3zr471t2k80000gn/T/ipykernel_6040/4062201101.py in <module>
#       1 print('Running Consumer #2')
#       2 while(True):
# ----> 3     results = consumer.poll(timeout_ms=1000)
#       4     if len(results) == 0:
#       5         print('no message')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# ~/opt/anaconda3/lib/python3.9/selectors.py in select(self, timeout)
#     560             ready = []
#     561             try:
# --> 562                 kev_list = self._selector.control(None, max_ev, timeout)
#     563             except InterruptedError:
#     564                 return ready
#
# KeyboardInterrupt:
